# %%
a=10
b=20
a+b
# Out:
# 30

# %%
def summ():
    x = int(input("enter the num"))
    y = int(input("enter 2nd num"))
    print("The sum of the numbers are",x+y)

# %%
summ()
# Out:
# enter the num45
# enter 2nd num4
# The sum of the numbers are 49

# %%
def summ():
    x = int(input("enter the num"))
    y = int(input("enter 2nd num"))
    s=x+y
    return s

# %%
summ()
# Out:
# enter the num34
# enter 2nd num34
# 68

# %%
x=print("d,fbedc")
# Out:
# d,fbedc

# %%
type(x)
# Out:
# NoneType

# %%
"sinbu"+"dskfjd"
# Out:
# 'sinbudskfjd'

# %%
y=print("fdkfjgda")
# Out:
# fdkfjgda

# %%
type(y)
# Out:
# NoneType

# %%
a = [12,1,24,5464,2443,1234,234345,56]

# %%
type(a)
# Out:
# list

# %%
import math

# %%
a.sort(reverse=True)

# %%
print(a)
# Out:
# [234345, 5464, 2443, 1234, 56, 24, 12, 1]

# %%
sum(a)
# Out:
# 243579
